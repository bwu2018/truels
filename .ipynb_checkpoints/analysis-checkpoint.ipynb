# %%
import pandas as pd

# %%
df = pd.read_csv("truel.csv")

# %%
df
# Out:
#       p1_p2_dist  p1_p3_dist  p2_p3_dist    p1_acc    p2_acc    p3_acc  \
# 0       0.600278    0.517168    0.123237  0.987987  0.887565  0.353948
# 1       0.600278    0.517168    0.123237  0.987987  0.887565  0.353948
# 2       0.600278    0.517168    0.123237  0.987987  0.887565  0.353948
# 3       0.600278    0.517168    0.123237  0.987987  0.887565  0.353948
# 4       0.600278    0.517168    0.123237  0.987987  0.887565  0.353948
# ...          ...         ...         ...       ...       ...       ...
# 7995    0.291011    0.674168    0.526214  0.601967  0.195244  0.111059
# 7996    0.291011    0.674168    0.526214  0.601967  0.195244  0.111059
# 7997    0.291011    0.674168    0.526214  0.601967  0.195244  0.111059
# 7998    0.291011    0.674168    0.526214  0.601967  0.195244  0.111059
# 7999    0.291011    0.674168    0.526214  0.601967  0.195244  0.111059
#
#       p1_target  p2_target  p3_target  p1_survive  p2_survive  p3_survive
# 0             2          1          1       0.097       0.093       0.703
# 1             2          1          2       0.201       0.038       0.679
# 2             2          3          1       0.578       0.090       0.000
# 3             2          3          2       0.910       0.019       0.000
# 4             3          1          1       0.057       0.806       0.000
# ...         ...        ...        ...         ...         ...         ...
# 7995          2          3          2       0.935       0.015       0.419
# 7996          3          1          1       0.394       0.641       0.242
# 7997          3          1          2       0.522       0.476       0.226
# 7998          3          3          1       0.690       0.394       0.041
# 7999          3          3          2       0.804       0.242       0.045
#
# [8000 rows x 12 columns]

# %%
equilibria = df.sort_values(["p1_p2_dist", "p1_p3_dist", "p2_p3_dist", "p1_acc", "p2_acc", "p3_acc"])
equilibria = equilibria.groupby(["p1_p2_dist", "p1_p3_dist", "p2_p3_dist", "p1_acc", "p2_acc", "p3_acc"])

# %%
equilibria.head(8)
# Out:
#       p1_p2_dist  p1_p3_dist  p2_p3_dist    p1_acc    p2_acc    p3_acc  \
# 4208    0.021901    0.443700    0.436485  0.832775  0.671416  0.531879
# 4209    0.021901    0.443700    0.436485  0.832775  0.671416  0.531879
# 4210    0.021901    0.443700    0.436485  0.832775  0.671416  0.531879
# 4211    0.021901    0.443700    0.436485  0.832775  0.671416  0.531879
# 4212    0.021901    0.443700    0.436485  0.832775  0.671416  0.531879
# ...          ...         ...         ...       ...       ...       ...
# 6107    1.124407    0.751278    0.760987  0.726002  0.713553  0.147992
# 6108    1.124407    0.751278    0.760987  0.726002  0.713553  0.147992
# 6109    1.124407    0.751278    0.760987  0.726002  0.713553  0.147992
# 6110    1.124407    0.751278    0.760987  0.726002  0.713553  0.147992
# 6111    1.124407    0.751278    0.760987  0.726002  0.713553  0.147992
#
#       p1_target  p2_target  p3_target  p1_survive  p2_survive  p3_survive
# 4208          2          1          1       0.026       0.000       0.968
# 4209          2          1          2       0.026       0.000       0.959
# 4210          2          3          1       0.395       0.000       0.228
# 4211          2          3          2       0.817       0.000       0.071
# 4212          3          1          1       0.003       0.888       0.061
# ...         ...        ...        ...         ...         ...         ...
# 6107          2          3          2       0.860       0.427       0.130
# 6108          3          1          1       0.429       0.858       0.133
# 6109          3          1          2       0.564       0.735       0.113
# 6110          3          3          1       0.702       0.818       0.017
# 6111          3          3          2       0.822       0.673       0.024
#
# [8000 rows x 12 columns]

# %%
new = []
temp = dict()
for group in range(len(equilibria)):
    rows = equilibria.get_group((list(equilibria.groups)[group]))
    print("Rows:",rows)
    for row in range(8):
        curr_row = rows.iloc[row]
        if curr_row["p1_survive"] > rows[(rows["p1_target"] != curr_row["p1_target"]) &
                                         (rows["p2_target"] == curr_row["p2_target"]) &
                                         (rows["p3_target"] == curr_row["p3_target"])]["p1_survive"].iloc[0]:
            if curr_row["p2_survive"] > rows[(rows["p1_target"] == curr_row["p1_target"]) &
                                         (rows["p2_target"] != curr_row["p2_target"]) &
                                         (rows["p3_target"] == curr_row["p3_target"])]["p2_survive"].iloc[0]:
                if curr_row["p3_survive"] > rows[(rows["p1_target"] == curr_row["p1_target"]) &
                                         (rows["p2_target"] == curr_row["p2_target"]) &
                                         (rows["p3_target"] != curr_row["p3_target"])]["p3_survive"].iloc[0]:
                    print("curr_row", curr_row)
                    new.append(curr_row)
                    if curr_row["p1_p2_dist"] not in temp:
                        temp[curr_row["p1_p2_dist"] = 1
                    else:
                        temp[curr_row["p1_p2_dist"]] += 1
# Out:
# Rows:       p1_p2_dist  p1_p3_dist  p2_p3_dist    p1_acc    p2_acc    p3_acc  \
# 4208    0.021901      0.4437    0.436485  0.832775  0.671416  0.531879
# 4209    0.021901      0.4437    0.436485  0.832775  0.671416  0.531879
# 4210    0.021901      0.4437    0.436485  0.832775  0.671416  0.531879
# 4211    0.021901      0.4437    0.436485  0.832775  0.671416  0.531879
# 4212    0.021901      0.4437    0.436485  0.832775  0.671416  0.531879
# 4213    0.021901      0.4437    0.436485  0.832775  0.671416  0.531879
# 4214    0.021901      0.4437    0.436485  0.832775  0.671416  0.531879
# 4215    0.021901      0.4437    0.436485  0.832775  0.671416  0.531879
#
#       p1_target  p2_target  p3_target  p1_survive  p2_survive  p3_survive
# 4208          2          1          1       0.026       0.000       0.968
# 4209          2          1          2       0.026       0.000       0.959
# 4210          2          3          1       0.395       0.000       0.228
# 4211          2          3          2       0.817       0.000       0.071
# 4212          3          1          1       0.003       0.888       0.061
# 4213          3          1          2       0.032       0.401       0.110
# 4214          3          3          1       0.031       0.505       0.009
# 4215          3          3          2       0.547       0.000       0.009
# curr_row p1_p2_dist    0.021901
# p1_p3_dist    0.443700
# p2_p3_dist    0.436485
# p1_acc        0.832775
# p2_acc        0.671416
# p3_acc        0.531879
# p1_target     3.000000
# p2_target     1.000000
# p3_target     2.000000
# p1_survive    0.032000
# p2_survive    0.401000
# p3_survive    0.110000
# Name: 4213, dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [36], in <cell line: 3>()
#      18 new.append(curr_row)
#      19 if curr_row["p1_p2_dist"] not in temp:
# ---> 20     temp.put(curr_row["p1_p2_dist"], 1)
#      21 else:
#      22     temp[curr_row["p1_p2_dist"]] += 1
#
# AttributeError: 'dict' object has no attribute 'put'

# %%
print(len(temp))
# Out:
# 850

# %%
new
# Out:
# [p1_p2_dist    0.021901
#  p1_p3_dist    0.443700
#  p2_p3_dist    0.436485
#  p1_acc        0.832775
#  p2_acc        0.671416
#  p3_acc        0.531879
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.032000
#  p2_survive    0.401000
#  p3_survive    0.110000
#  Name: 4213, dtype: float64,
#  p1_p2_dist    0.039336
#  p1_p3_dist    0.799133
#  p2_p3_dist    0.760904
#  p1_acc        0.491423
#  p2_acc        0.280181
#  p3_acc        0.134676
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.409000
#  p2_survive    0.151000
#  p3_survive    0.842000
#  Name: 6960, dtype: float64,
#  p1_p2_dist    0.046637
#  p1_p3_dist    0.234732
#  p2_p3_dist    0.191840
#  p1_acc        0.052353
#  p2_acc        0.024346
#  p3_acc        0.013678
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.716000
#  p2_survive    0.251000
#  p3_survive    0.940000
#  Name: 5809, dtype: float64,
#  p1_p2_dist    0.050039
#  p1_p3_dist    0.063812
#  p2_p3_dist    0.104122
#  p1_acc        0.716362
#  p2_acc        0.519797
#  p3_acc        0.388252
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.384000
#  p2_survive    0.011000
#  p3_survive    0.169000
#  Name: 2346, dtype: float64,
#  p1_p2_dist    0.050039
#  p1_p3_dist    0.063812
#  p2_p3_dist    0.104122
#  p1_acc        0.716362
#  p2_acc        0.519797
#  p3_acc        0.388252
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.187000
#  p2_survive    0.361000
#  p3_survive    0.014000
#  Name: 2349, dtype: float64,
#  p1_p2_dist    0.050530
#  p1_p3_dist    0.229702
#  p2_p3_dist    0.194424
#  p1_acc        0.393387
#  p2_acc        0.218344
#  p3_acc        0.172693
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.328000
#  p2_survive    0.221000
#  p3_survive    0.749000
#  Name: 3568, dtype: float64,
#  p1_p2_dist    0.061745
#  p1_p3_dist    0.250177
#  p2_p3_dist    0.299477
#  p1_acc        0.293569
#  p2_acc        0.208303
#  p3_acc        0.153756
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.302000
#  p2_survive    0.280000
#  p3_survive    0.777000
#  Name: 4480, dtype: float64,
#  p1_p2_dist    0.062030
#  p1_p3_dist    0.625209
#  p2_p3_dist    0.570824
#  p1_acc        0.299010
#  p2_acc        0.245452
#  p3_acc        0.082706
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.377000
#  p2_survive    0.334000
#  p3_survive    0.842000
#  Name: 4096, dtype: float64,
#  p1_p2_dist    0.073924
#  p1_p3_dist    0.508358
#  p2_p3_dist    0.550084
#  p1_acc        0.573038
#  p2_acc        0.531102
#  p3_acc        0.080091
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.189000
#  p2_survive    0.168000
#  p3_survive    0.837000
#  Name: 5032, dtype: float64,
#  p1_p2_dist    0.074828
#  p1_p3_dist    0.755723
#  p2_p3_dist    0.704973
#  p1_acc        0.657829
#  p2_acc        0.591267
#  p3_acc        0.217542
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.151000
#  p2_survive    0.081000
#  p3_survive    0.891000
#  Name: 1744, dtype: float64,
#  p1_p2_dist    0.091209
#  p1_p3_dist    0.263046
#  p2_p3_dist    0.215703
#  p1_acc        0.572217
#  p2_acc        0.409001
#  p3_acc        0.035650
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.353000
#  p2_survive    0.138000
#  p3_survive    0.679000
#  Name: 5832, dtype: float64,
#  p1_p2_dist    0.092316
#  p1_p3_dist    0.306296
#  p2_p3_dist    0.241472
#  p1_acc        0.340407
#  p2_acc        0.315642
#  p3_acc        0.253633
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.162000
#  p2_survive    0.320000
#  p3_survive    0.754000
#  Name: 1536, dtype: float64,
#  p1_p2_dist    0.095208
#  p1_p3_dist    0.940662
#  p2_p3_dist    0.928209
#  p1_acc        0.492491
#  p2_acc        0.411903
#  p3_acc        0.400487
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.233000
#  p2_survive    0.219000
#  p3_survive    0.893000
#  Name: 5272, dtype: float64,
#  p1_p2_dist    0.096532
#  p1_p3_dist    0.770367
#  p2_p3_dist    0.831191
#  p1_acc        0.676462
#  p2_acc        0.477394
#  p3_acc        0.014823
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.355000
#  p2_survive    0.082000
#  p3_survive    0.817000
#  Name: 833, dtype: float64,
#  p1_p2_dist    0.098208
#  p1_p3_dist    0.588703
#  p2_p3_dist    0.553909
#  p1_acc        0.600296
#  p2_acc        0.408759
#  p3_acc        0.332802
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.219000
#  p2_survive    0.133000
#  p3_survive    0.786000
#  Name: 6800, dtype: float64,
#  p1_p2_dist    0.110062
#  p1_p3_dist    0.512797
#  p2_p3_dist    0.490314
#  p1_acc        0.607041
#  p2_acc        0.304216
#  p3_acc        0.029278
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.529000
#  p2_survive    0.078000
#  p3_survive    0.683000
#  Name: 2856, dtype: float64,
#  p1_p2_dist    0.113566
#  p1_p3_dist    0.537849
#  p2_p3_dist    0.576147
#  p1_acc        0.302810
#  p2_acc        0.296964
#  p3_acc        0.288305
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.357000
#  p2_survive    0.205000
#  p3_survive    0.830000
#  Name: 6985, dtype: float64,
#  p1_p2_dist    0.117902
#  p1_p3_dist    0.731248
#  p2_p3_dist    0.827161
#  p1_acc        0.617959
#  p2_acc        0.439745
#  p3_acc        0.373192
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.200000
#  p2_survive    0.118000
#  p3_survive    0.841000
#  Name: 6640, dtype: float64,
#  p1_p2_dist    0.118432
#  p1_p3_dist    0.512655
#  p2_p3_dist    0.625506
#  p1_acc        0.410100
#  p2_acc        0.340421
#  p3_acc        0.339667
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.168000
#  p2_survive    0.244000
#  p3_survive    0.835000
#  Name: 7104, dtype: float64,
#  p1_p2_dist    0.124757
#  p1_p3_dist    0.457826
#  p2_p3_dist    0.458831
#  p1_acc        0.769276
#  p2_acc        0.561745
#  p3_acc        0.266253
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.134000
#  p2_survive    0.005000
#  p3_survive    0.866000
#  Name: 7912, dtype: float64,
#  p1_p2_dist    0.124772
#  p1_p3_dist    0.648935
#  p2_p3_dist    0.658481
#  p1_acc        0.511935
#  p2_acc        0.404815
#  p3_acc        0.245879
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.235000
#  p2_survive    0.198000
#  p3_survive    0.796000
#  Name: 4936, dtype: float64,
#  p1_p2_dist    0.127434
#  p1_p3_dist    0.547775
#  p2_p3_dist    0.481422
#  p1_acc        0.348909
#  p2_acc        0.319773
#  p3_acc        0.016761
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.384000
#  p2_survive    0.354000
#  p3_survive    0.783000
#  Name: 2880, dtype: float64,
#  p1_p2_dist    0.133940
#  p1_p3_dist    0.620842
#  p2_p3_dist    0.671350
#  p1_acc        0.581858
#  p2_acc        0.061061
#  p3_acc        0.041706
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.862000
#  p2_survive    0.026000
#  p3_survive    0.605000
#  Name: 7697, dtype: float64,
#  p1_p2_dist    0.138130
#  p1_p3_dist    0.648151
#  p2_p3_dist    0.555485
#  p1_acc        0.775940
#  p2_acc        0.477190
#  p3_acc        0.336175
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.218000
#  p2_survive    0.006000
#  p3_survive    0.825000
#  Name: 4384, dtype: float64,
#  p1_p2_dist    0.140977
#  p1_p3_dist    0.449536
#  p2_p3_dist    0.474749
#  p1_acc        0.548665
#  p2_acc        0.517738
#  p3_acc        0.326096
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.114000
#  p2_survive    0.167000
#  p3_survive    0.798000
#  Name: 7056, dtype: float64,
#  p1_p2_dist    0.146382
#  p1_p3_dist    0.954687
#  p2_p3_dist    1.049582
#  p1_acc        0.745066
#  p2_acc        0.534448
#  p3_acc        0.505377
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.198000
#  p2_survive    0.037000
#  p3_survive    0.901000
#  Name: 408, dtype: float64,
#  p1_p2_dist    0.146728
#  p1_p3_dist    0.469911
#  p2_p3_dist    0.616200
#  p1_acc        0.650301
#  p2_acc        0.562800
#  p3_acc        0.269728
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.147000
#  p2_survive    0.103000
#  p3_survive    0.814000
#  Name: 7800, dtype: float64,
#  p1_p2_dist    0.150056
#  p1_p3_dist    0.546392
#  p2_p3_dist    0.482234
#  p1_acc        0.732317
#  p2_acc        0.528731
#  p3_acc        0.404070
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.147000
#  p2_survive    0.036000
#  p3_survive    0.844000
#  Name: 5048, dtype: float64,
#  p1_p2_dist    0.163192
#  p1_p3_dist    0.993754
#  p2_p3_dist    0.843790
#  p1_acc        0.776907
#  p2_acc        0.401109
#  p3_acc        0.018541
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.461000
#  p2_survive    0.018000
#  p3_survive    0.857000
#  Name: 5664, dtype: float64,
#  p1_p2_dist    0.163864
#  p1_p3_dist    0.380908
#  p2_p3_dist    0.218413
#  p1_acc        0.485299
#  p2_acc        0.197829
#  p3_acc        0.037560
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.595000
#  p2_survive    0.143000
#  p3_survive    0.641000
#  Name: 5992, dtype: float64,
#  p1_p2_dist    0.164467
#  p1_p3_dist    0.215890
#  p2_p3_dist    0.287981
#  p1_acc        0.583893
#  p2_acc        0.451672
#  p3_acc        0.406699
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.375000
#  p2_survive    0.132000
#  p3_survive    0.258000
#  Name: 1546, dtype: float64,
#  p1_p2_dist    0.164467
#  p1_p3_dist    0.215890
#  p2_p3_dist    0.287981
#  p1_acc        0.583893
#  p2_acc        0.451672
#  p3_acc        0.406699
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.261000
#  p2_survive    0.330000
#  p3_survive    0.159000
#  Name: 1549, dtype: float64,
#  p1_p2_dist    0.165007
#  p1_p3_dist    0.067142
#  p2_p3_dist    0.209218
#  p1_acc        0.702164
#  p2_acc        0.520302
#  p3_acc        0.085207
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.254000
#  p2_survive    0.079000
#  p3_survive    0.675000
#  Name: 6704, dtype: float64,
#  p1_p2_dist    0.169335
#  p1_p3_dist    0.940220
#  p2_p3_dist    0.771805
#  p1_acc        0.552128
#  p2_acc        0.344074
#  p3_acc        0.098514
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.466000
#  p2_survive    0.130000
#  p3_survive    0.832000
#  Name: 7929, dtype: float64,
#  p1_p2_dist    0.171556
#  p1_p3_dist    0.708807
#  p2_p3_dist    0.788587
#  p1_acc        0.542154
#  p2_acc        0.431809
#  p3_acc        0.115612
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.334000
#  p2_survive    0.165000
#  p3_survive    0.819000
#  Name: 273, dtype: float64,
#  p1_p2_dist    0.175395
#  p1_p3_dist    0.456520
#  p2_p3_dist    0.631008
#  p1_acc        0.652289
#  p2_acc        0.474777
#  p3_acc        0.030189
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.341000
#  p2_survive    0.102000
#  p3_survive    0.742000
#  Name: 6256, dtype: float64,
#  p1_p2_dist    0.175410
#  p1_p3_dist    0.251779
#  p2_p3_dist    0.222922
#  p1_acc        0.549257
#  p2_acc        0.534973
#  p3_acc        0.351995
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.155000
#  p2_survive    0.096000
#  p3_survive    0.746000
#  Name: 5313, dtype: float64,
#  p1_p2_dist    0.177387
#  p1_p3_dist    0.287948
#  p2_p3_dist    0.447161
#  p1_acc        0.479597
#  p2_acc        0.430465
#  p3_acc        0.144434
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.230000
#  p2_survive    0.230000
#  p3_survive    0.753000
#  Name: 6288, dtype: float64,
#  p1_p2_dist    0.180958
#  p1_p3_dist    0.949426
#  p2_p3_dist    0.804851
#  p1_acc        0.576592
#  p2_acc        0.309714
#  p3_acc        0.253044
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.421000
#  p2_survive    0.130000
#  p3_survive    0.831000
#  Name: 4240, dtype: float64,
#  p1_p2_dist    0.181166
#  p1_p3_dist    0.201980
#  p2_p3_dist    0.347619
#  p1_acc        0.711253
#  p2_acc        0.286582
#  p3_acc        0.048033
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.528000
#  p2_survive    0.046000
#  p3_survive    0.515000
#  Name: 4440, dtype: float64,
#  p1_p2_dist    0.184186
#  p1_p3_dist    0.402023
#  p2_p3_dist    0.298955
#  p1_acc        0.071222
#  p2_acc        0.032777
#  p3_acc        0.022475
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.560000
#  p2_survive    0.392000
#  p3_survive    0.949000
#  Name: 3976, dtype: float64,
#  p1_p2_dist    0.187591
#  p1_p3_dist    0.610452
#  p2_p3_dist    0.438292
#  p1_acc        0.541467
#  p2_acc        0.262920
#  p3_acc        0.210925
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.384000
#  p2_survive    0.136000
#  p3_survive    0.739000
#  Name: 4912, dtype: float64,
#  p1_p2_dist    0.193905
#  p1_p3_dist    0.847905
#  p2_p3_dist    1.032731
#  p1_acc        0.264733
#  p2_acc        0.103183
#  p3_acc        0.099720
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.593000
#  p2_survive    0.242000
#  p3_survive    0.895000
#  Name: 1376, dtype: float64,
#  p1_p2_dist    0.194025
#  p1_p3_dist    0.525113
#  p2_p3_dist    0.459296
#  p1_acc        0.652411
#  p2_acc        0.597124
#  p3_acc        0.321513
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.108000
#  p2_survive    0.116000
#  p3_survive    0.821000
#  Name: 5656, dtype: float64,
#  p1_p2_dist    0.196545
#  p1_p3_dist    0.172279
#  p2_p3_dist    0.197051
#  p1_acc        0.520977
#  p2_acc        0.410500
#  p3_acc        0.403249
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.339000
#  p2_survive    0.192000
#  p3_survive    0.293000
#  Name: 3122, dtype: float64,
#  p1_p2_dist    0.196545
#  p1_p3_dist    0.172279
#  p2_p3_dist    0.197051
#  p1_acc        0.520977
#  p2_acc        0.410500
#  p3_acc        0.403249
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.312000
#  p2_survive    0.299000
#  p3_survive    0.185000
#  Name: 3125, dtype: float64,
#  p1_p2_dist    0.197515
#  p1_p3_dist    0.376238
#  p2_p3_dist    0.498121
#  p1_acc        0.792847
#  p2_acc        0.357798
#  p3_acc        0.242100
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.327000
#  p2_survive    0.014000
#  p3_survive    0.619000
#  Name: 1624, dtype: float64,
#  p1_p2_dist    0.198102
#  p1_p3_dist    0.654487
#  p2_p3_dist    0.469107
#  p1_acc        0.661352
#  p2_acc        0.353711
#  p3_acc        0.024319
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.478000
#  p2_survive    0.101000
#  p3_survive    0.714000
#  Name: 5848, dtype: float64,
#  p1_p2_dist    0.198405
#  p1_p3_dist    0.451523
#  p2_p3_dist    0.280594
#  p1_acc        0.822068
#  p2_acc        0.615300
#  p3_acc        0.139919
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.184000
#  p2_survive    0.002000
#  p3_survive    0.837000
#  Name: 2536, dtype: float64,
#  p1_p2_dist    0.199064
#  p1_p3_dist    0.856937
#  p2_p3_dist    0.674730
#  p1_acc        0.791621
#  p2_acc        0.396867
#  p3_acc        0.059146
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.515000
#  p2_survive    0.019000
#  p3_survive    0.775000
#  Name: 5225, dtype: float64,
#  p1_p2_dist    0.199806
#  p1_p3_dist    0.944755
#  p2_p3_dist    0.969292
#  p1_acc        0.682462
#  p2_acc        0.426683
#  p3_acc        0.101232
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.396000
#  p2_survive    0.103000
#  p3_survive    0.853000
#  Name: 1640, dtype: float64,
#  p1_p2_dist    0.201649
#  p1_p3_dist    0.320361
#  p2_p3_dist    0.150971
#  p1_acc        0.744575
#  p2_acc        0.491013
#  p3_acc        0.166922
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.243000
#  p2_survive    0.054000
#  p3_survive    0.730000
#  Name: 1288, dtype: float64,
#  p1_p2_dist    0.201718
#  p1_p3_dist    0.560652
#  p2_p3_dist    0.472212
#  p1_acc        0.461542
#  p2_acc        0.445445
#  p3_acc        0.069522
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.284000
#  p2_survive    0.275000
#  p3_survive    0.759000
#  Name: 680, dtype: float64,
#  p1_p2_dist    0.201796
#  p1_p3_dist    0.188509
#  p2_p3_dist    0.235635
#  p1_acc        0.805553
#  p2_acc        0.531562
#  p3_acc        0.232901
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.160000
#  p2_survive    0.011000
#  p3_survive    0.755000
#  Name: 1368, dtype: float64,
#  p1_p2_dist    0.203501
#  p1_p3_dist    0.500614
#  p2_p3_dist    0.431763
#  p1_acc        0.526882
#  p2_acc        0.364551
#  p3_acc        0.126241
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.333000
#  p2_survive    0.185000
#  p3_survive    0.744000
#  Name: 2328, dtype: float64,
#  p1_p2_dist    0.207981
#  p1_p3_dist    0.537342
#  p2_p3_dist    0.731315
#  p1_acc        0.721518
#  p2_acc        0.209371
#  p3_acc        0.023731
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.652000
#  p2_survive    0.040000
#  p3_survive    0.546000
#  Name: 1224, dtype: float64,
#  p1_p2_dist    0.208040
#  p1_p3_dist    0.811485
#  p2_p3_dist    0.959988
#  p1_acc        0.321223
#  p2_acc        0.206944
#  p3_acc        0.141472
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.533000
#  p2_survive    0.218000
#  p3_survive    0.871000
#  Name: 1193, dtype: float64,
#  p1_p2_dist    0.208124
#  p1_p3_dist    0.849117
#  p2_p3_dist    1.044338
#  p1_acc        0.743518
#  p2_acc        0.654254
#  p3_acc        0.451293
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.108000
#  p2_survive    0.073000
#  p3_survive    0.919000
#  Name: 4688, dtype: float64,
#  p1_p2_dist    0.211014
#  p1_p3_dist    0.836043
#  p2_p3_dist    0.912729
#  p1_acc        0.725545
#  p2_acc        0.652954
#  p3_acc        0.025610
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.173000
#  p2_survive    0.114000
#  p3_survive    0.891000
#  Name: 5008, dtype: float64,
#  p1_p2_dist    0.211929
#  p1_p3_dist    0.992778
#  p2_p3_dist    0.909600
#  p1_acc        0.808331
#  p2_acc        0.528900
#  p3_acc        0.095136
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.320000
#  p2_survive    0.013000
#  p3_survive    0.892000
#  Name: 1000, dtype: float64,
#  p1_p2_dist    0.212914
#  p1_p3_dist    0.912547
#  p2_p3_dist    0.942744
#  p1_acc        0.753141
#  p2_acc        0.474852
#  p3_acc        0.451982
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.251000
#  p2_survive    0.054000
#  p3_survive    0.865000
#  Name: 7856, dtype: float64,
#  p1_p2_dist    0.215374
#  p1_p3_dist    0.919816
#  p2_p3_dist    0.853942
#  p1_acc        0.703135
#  p2_acc        0.617388
#  p3_acc        0.148354
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.209000
#  p2_survive    0.092000
#  p3_survive    0.892000
#  Name: 1817, dtype: float64,
#  p1_p2_dist    0.217084
#  p1_p3_dist    0.607804
#  p2_p3_dist    0.789704
#  p1_acc        0.357433
#  p2_acc        0.317341
#  p3_acc        0.258058
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.249000
#  p2_survive    0.344000
#  p3_survive    0.841000
#  Name: 208, dtype: float64,
#  p1_p2_dist    0.217132
#  p1_p3_dist    0.797755
#  p2_p3_dist    0.779130
#  p1_acc        0.625168
#  p2_acc        0.407796
#  p3_acc        0.149968
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.392000
#  p2_survive    0.137000
#  p3_survive    0.812000
#  Name: 1601, dtype: float64,
#  p1_p2_dist    0.219972
#  p1_p3_dist    0.528412
#  p2_p3_dist    0.308449
#  p1_acc        0.765361
#  p2_acc        0.205235
#  p3_acc        0.196834
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.507000
#  p2_survive    0.030000
#  p3_survive    0.582000
#  Name: 2672, dtype: float64,
#  p1_p2_dist    0.220881
#  p1_p3_dist    0.804666
#  p2_p3_dist    0.759353
#  p1_acc        0.774534
#  p2_acc        0.391355
#  p3_acc        0.259348
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.359000
#  p2_survive    0.041000
#  p3_survive    0.790000
#  Name: 3720, dtype: float64,
#  p1_p2_dist    0.221213
#  p1_p3_dist    0.651558
#  p2_p3_dist    0.586201
#  p1_acc        0.388494
#  p2_acc        0.387035
#  p3_acc        0.009135
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.338000
#  p2_survive    0.363000
#  p3_survive    0.794000
#  Name: 4840, dtype: float64,
#  p1_p2_dist    0.223331
#  p1_p3_dist    0.207440
#  p2_p3_dist    0.035613
#  p1_acc        0.796215
#  p2_acc        0.090667
#  p3_acc        0.028728
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.828000
#  p2_survive    0.011000
#  p3_survive    0.170000
#  Name: 7272, dtype: float64,
#  p1_p2_dist    0.224991
#  p1_p3_dist    0.150752
#  p2_p3_dist    0.308711
#  p1_acc        0.428691
#  p2_acc        0.240366
#  p3_acc        0.223653
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.525000
#  p2_survive    0.405000
#  p3_survive    0.193000
#  Name: 6797, dtype: float64,
#  p1_p2_dist    0.225029
#  p1_p3_dist    0.733880
#  p2_p3_dist    0.538127
#  p1_acc        0.484906
#  p2_acc        0.340364
#  p3_acc        0.212759
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.293000
#  p2_survive    0.204000
#  p3_survive    0.809000
#  Name: 6712, dtype: float64,
#  p1_p2_dist    0.227528
#  p1_p3_dist    0.707460
#  p2_p3_dist    0.643200
#  p1_acc        0.835126
#  p2_acc        0.165332
#  p3_acc        0.066958
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.731000
#  p2_survive    0.005000
#  p3_survive    0.556000
#  Name: 7952, dtype: float64,
#  p1_p2_dist    0.230405
#  p1_p3_dist    0.679931
#  p2_p3_dist    0.789276
#  p1_acc        0.358675
#  p2_acc        0.147463
#  p3_acc        0.077427
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.568000
#  p2_survive    0.231000
#  p3_survive    0.819000
#  Name: 4552, dtype: float64,
#  p1_p2_dist    0.230931
#  p1_p3_dist    0.560898
#  p2_p3_dist    0.501664
#  p1_acc        0.782336
#  p2_acc        0.160088
#  p3_acc        0.094921
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.678000
#  p2_survive    0.015000
#  p3_survive    0.509000
#  Name: 7320, dtype: float64,
#  p1_p2_dist    0.231697
#  p1_p3_dist    0.223915
#  p2_p3_dist    0.407764
#  p1_acc        0.635331
#  p2_acc        0.477425
#  p3_acc        0.082350
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.260000
#  p2_survive    0.162000
#  p3_survive    0.697000
#  Name: 5784, dtype: float64,
#  p1_p2_dist    0.233794
#  p1_p3_dist    0.653124
#  p2_p3_dist    0.458591
#  p1_acc        0.829668
#  p2_acc        0.479137
#  p3_acc        0.006895
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.404000
#  p2_survive    0.011000
#  p3_survive    0.725000
#  Name: 1984, dtype: float64,
#  p1_p2_dist    0.234388
#  p1_p3_dist    0.651245
#  p2_p3_dist    0.870949
#  p1_acc        0.352619
#  p2_acc        0.346932
#  p3_acc        0.330796
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.192000
#  p2_survive    0.332000
#  p3_survive    0.844000
#  Name: 1656, dtype: float64,
#  p1_p2_dist    0.236821
#  p1_p3_dist    0.625971
#  p2_p3_dist    0.459029
#  p1_acc        0.806218
#  p2_acc        0.422505
#  p3_acc        0.013590
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.454000
#  p2_survive    0.026000
#  p3_survive    0.704000
#  Name: 3864, dtype: float64,
#  p1_p2_dist    0.237873
#  p1_p3_dist    0.665720
#  p2_p3_dist    0.716513
#  p1_acc        0.526736
#  p2_acc        0.469290
#  p3_acc        0.360487
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.165000
#  p2_survive    0.218000
#  p3_survive    0.818000
#  Name: 48, dtype: float64,
#  p1_p2_dist    0.237972
#  p1_p3_dist    0.560161
#  p2_p3_dist    0.368428
#  p1_acc        0.426211
#  p2_acc        0.323893
#  p3_acc        0.048355
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.452000
#  p2_survive    0.234000
#  p3_survive    0.747000
#  Name: 6881, dtype: float64,
#  p1_p2_dist    0.239502
#  p1_p3_dist    0.168262
#  p2_p3_dist    0.405034
#  p1_acc        0.794021
#  p2_acc        0.425984
#  p3_acc        0.265399
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.220000
#  p2_survive    0.035000
#  p3_survive    0.681000
#  Name: 4464, dtype: float64,
#  p1_p2_dist    0.243053
#  p1_p3_dist    0.636491
#  p2_p3_dist    0.506853
#  p1_acc        0.766595
#  p2_acc        0.587398
#  p3_acc        0.163367
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.212000
#  p2_survive    0.064000
#  p3_survive    0.813000
#  Name: 6248, dtype: float64,
#  p1_p2_dist    0.244017
#  p1_p3_dist    0.613604
#  p2_p3_dist    0.716488
#  p1_acc        0.714944
#  p2_acc        0.559274
#  p3_acc        0.160921
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.224000
#  p2_survive    0.096000
#  p3_survive    0.814000
#  Name: 3424, dtype: float64,
#  p1_p2_dist    0.246165
#  p1_p3_dist    0.648705
#  p2_p3_dist    0.601252
#  p1_acc        0.795951
#  p2_acc        0.708967
#  p3_acc        0.127960
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.139000
#  p2_survive    0.052000
#  p3_survive    0.868000
#  Name: 7840, dtype: float64,
#  p1_p2_dist    0.247272
#  p1_p3_dist    0.687545
#  p2_p3_dist    0.534486
#  p1_acc        0.791695
#  p2_acc        0.520211
#  p3_acc        0.058672
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.350000
#  p2_survive    0.042000
#  p3_survive    0.769000
#  Name: 4153, dtype: float64,
#  p1_p2_dist    0.247563
#  p1_p3_dist    0.343903
#  p2_p3_dist    0.292722
#  p1_acc        0.702362
#  p2_acc        0.236868
#  p3_acc        0.105362
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.521000
#  p2_survive    0.068000
#  p3_survive    0.550000
#  Name: 5512, dtype: float64,
#  p1_p2_dist    0.251295
#  p1_p3_dist    0.449229
#  p2_p3_dist    0.244633
#  p1_acc        0.637500
#  p2_acc        0.540111
#  p3_acc        0.144349
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.244000
#  p2_survive    0.166000
#  p3_survive    0.724000
#  Name: 1016, dtype: float64,
#  p1_p2_dist    0.253700
#  p1_p3_dist    0.836104
#  p2_p3_dist    0.628758
#  p1_acc        0.838389
#  p2_acc        0.598646
#  p3_acc        0.114996
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.254000
#  p2_survive    0.013000
#  p3_survive    0.863000
#  Name: 5384, dtype: float64,
#  p1_p2_dist    0.255061
#  p1_p3_dist    0.648722
#  p2_p3_dist    0.831870
#  p1_acc        0.753880
#  p2_acc        0.224622
#  p3_acc        0.181970
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.534000
#  p2_survive    0.040000
#  p3_survive    0.629000
#  Name: 952, dtype: float64,
#  p1_p2_dist    0.256601
#  p1_p3_dist    0.696541
#  p2_p3_dist    0.774156
#  p1_acc        0.555986
#  p2_acc        0.351589
#  p3_acc        0.011363
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.486000
#  p2_survive    0.189000
#  p3_survive    0.781000
#  Name: 7385, dtype: float64,
#  p1_p2_dist    0.257425
#  p1_p3_dist    0.933289
#  p2_p3_dist    1.015994
#  p1_acc        0.244331
#  p2_acc        0.152994
#  p3_acc        0.085499
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.567000
#  p2_survive    0.262000
#  p3_survive    0.925000
#  Name: 4129, dtype: float64,
#  p1_p2_dist    0.257659
#  p1_p3_dist    0.321474
#  p2_p3_dist    0.293372
#  p1_acc        0.896407
#  p2_acc        0.796985
#  p3_acc        0.660566
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.054000
#  p2_survive    0.241000
#  p3_survive    0.021000
#  Name: 2445, dtype: float64,
#  p1_p2_dist    0.258615
#  p1_p3_dist    0.716047
#  p2_p3_dist    0.801953
#  p1_acc        0.668631
#  p2_acc        0.658309
#  p3_acc        0.172031
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.154000
#  p2_survive    0.167000
#  p3_survive    0.848000
#  Name: 96, dtype: float64,
#  p1_p2_dist    0.261222
#  p1_p3_dist    0.211621
#  p2_p3_dist    0.452369
#  p1_acc        0.720485
#  p2_acc        0.533882
#  p3_acc        0.006604
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.329000
#  p2_survive    0.107000
#  p3_survive    0.652000
#  Name: 7753, dtype: float64,
#  p1_p2_dist    0.261315
#  p1_p3_dist    0.336114
#  p2_p3_dist    0.417815
#  p1_acc        0.711304
#  p2_acc        0.498093
#  p3_acc        0.089351
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.353000
#  p2_survive    0.080000
#  p3_survive    0.668000
#  Name: 4001, dtype: float64,
#  p1_p2_dist    0.261445
#  p1_p3_dist    0.441239
#  p2_p3_dist    0.693111
#  p1_acc        0.768677
#  p2_acc        0.669339
#  p3_acc        0.606112
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.258000
#  p2_survive    0.054000
#  p3_survive    0.359000
#  Name: 3330, dtype: float64,
#  p1_p2_dist    0.261445
#  p1_p3_dist    0.441239
#  p2_p3_dist    0.693111
#  p1_acc        0.768677
#  p2_acc        0.669339
#  p3_acc        0.606112
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.122000
#  p2_survive    0.410000
#  p3_survive    0.160000
#  Name: 3333, dtype: float64,
#  p1_p2_dist    0.263157
#  p1_p3_dist    0.260650
#  p2_p3_dist    0.005511
#  p1_acc        0.570551
#  p2_acc        0.439634
#  p3_acc        0.243165
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.173000
#  p2_survive    0.181000
#  p3_survive    0.650000
#  Name: 4832, dtype: float64,
#  p1_p2_dist    0.263689
#  p1_p3_dist    0.554155
#  p2_p3_dist    0.728605
#  p1_acc        0.750879
#  p2_acc        0.553127
#  p3_acc        0.411235
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.153000
#  p2_survive    0.071000
#  p3_survive    0.819000
#  Name: 6768, dtype: float64,
#  p1_p2_dist    0.266069
#  p1_p3_dist    0.840144
#  p2_p3_dist    0.630691
#  p1_acc        0.680829
#  p2_acc        0.545564
#  p3_acc        0.377162
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.196000
#  p2_survive    0.112000
#  p3_survive    0.843000
#  Name: 5520, dtype: float64,
#  p1_p2_dist    0.266277
#  p1_p3_dist    0.497366
#  p2_p3_dist    0.236660
#  p1_acc        0.847419
#  p2_acc        0.814754
#  p3_acc        0.281042
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.027000
#  p2_survive    0.015000
#  p3_survive    0.946000
#  Name: 7256, dtype: float64,
#  p1_p2_dist    0.266445
#  p1_p3_dist    0.707321
#  p2_p3_dist    0.472749
#  p1_acc        0.482008
#  p2_acc        0.012144
#  p3_acc        0.002705
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.967000
#  p2_survive    0.010000
#  p3_survive    0.688000
#  Name: 5888, dtype: float64,
#  p1_p2_dist    0.266752
#  p1_p3_dist    0.951104
#  p2_p3_dist    0.696204
#  p1_acc        0.674839
#  p2_acc        0.301429
#  p3_acc        0.057569
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.612000
#  p2_survive    0.078000
#  p3_survive    0.783000
#  Name: 1321, dtype: float64,
#  p1_p2_dist    0.268023
#  p1_p3_dist    0.407950
#  p2_p3_dist    0.512953
#  p1_acc        0.834194
#  p2_acc        0.313675
#  p3_acc        0.117157
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.495000
#  p2_survive    0.018000
#  p3_survive    0.518000
#  Name: 7176, dtype: float64,
#  p1_p2_dist    0.269742
#  p1_p3_dist    0.350771
#  p2_p3_dist    0.613779
#  p1_acc        0.852007
#  p2_acc        0.788494
#  p3_acc        0.275600
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.048000
#  p2_survive    0.015000
#  p3_survive    0.929000
#  Name: 6144, dtype: float64,
#  p1_p2_dist    0.271465
#  p1_p3_dist    0.698604
#  p2_p3_dist    0.432922
#  p1_acc        0.696783
#  p2_acc        0.171248
#  p3_acc        0.073210
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.676000
#  p2_survive    0.061000
#  p3_survive    0.657000
#  Name: 6024, dtype: float64,
#  p1_p2_dist    0.271746
#  p1_p3_dist    0.504316
#  p2_p3_dist    0.330183
#  p1_acc        0.822989
#  p2_acc        0.408711
#  p3_acc        0.359791
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.236000
#  p2_survive    0.026000
#  p3_survive    0.718000
#  Name: 3656, dtype: float64,
#  p1_p2_dist    0.274315
#  p1_p3_dist    0.721727
#  p2_p3_dist    0.516713
#  p1_acc        0.623382
#  p2_acc        0.519933
#  p3_acc        0.122071
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.259000
#  p2_survive    0.190000
#  p3_survive    0.780000
#  Name: 6976, dtype: float64,
#  p1_p2_dist    0.276965
#  p1_p3_dist    0.488211
#  p2_p3_dist    0.548193
#  p1_acc        0.816194
#  p2_acc        0.810524
#  p3_acc        0.511504
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.041000
#  p2_survive    0.473000
#  p3_survive    0.138000
#  Name: 1357, dtype: float64,
#  p1_p2_dist    0.280386
#  p1_p3_dist    0.501846
#  p2_p3_dist    0.624042
#  p1_acc        0.865512
#  p2_acc        0.582835
#  p3_acc        0.083123
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.296000
#  p2_survive    0.007000
#  p3_survive    0.759000
#  Name: 281, dtype: float64,
#  p1_p2_dist    0.282077
#  p1_p3_dist    0.873355
#  p2_p3_dist    0.643001
#  p1_acc        0.250608
#  p2_acc        0.059582
#  p3_acc        0.032986
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.741000
#  p2_survive    0.175000
#  p3_survive    0.908000
#  Name: 3320, dtype: float64,
#  p1_p2_dist    0.283848
#  p1_p3_dist    0.253131
#  p2_p3_dist    0.312163
#  p1_acc        0.717676
#  p2_acc        0.410672
#  p3_acc        0.043228
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.448000
#  p2_survive    0.088000
#  p3_survive    0.563000
#  Name: 5976, dtype: float64,
#  p1_p2_dist    0.283881
#  p1_p3_dist    0.291299
#  p2_p3_dist    0.564043
#  p1_acc        0.820661
#  p2_acc        0.532014
#  p3_acc        0.389393
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.136000
#  p2_survive    0.039000
#  p3_survive    0.794000
#  Name: 2832, dtype: float64,
#  p1_p2_dist    0.286611
#  p1_p3_dist    1.105614
#  p2_p3_dist    1.043998
#  p1_acc        0.869849
#  p2_acc        0.465986
#  p3_acc        0.124556
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.474000
#  p2_survive    0.007000
#  p3_survive    0.879000
#  Name: 3297, dtype: float64,
#  p1_p2_dist    0.289669
#  p1_p3_dist    0.602986
#  p2_p3_dist    0.395545
#  p1_acc        0.749096
#  p2_acc        0.690241
#  p3_acc        0.321314
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.106000
#  p2_survive    0.096000
#  p3_survive    0.821000
#  Name: 4608, dtype: float64,
#  p1_p2_dist    0.289754
#  p1_p3_dist    0.860176
#  p2_p3_dist    0.713913
#  p1_acc        0.559320
#  p2_acc        0.260512
#  p3_acc        0.170783
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.565000
#  p2_survive    0.130000
#  p3_survive    0.814000
#  Name: 1329, dtype: float64,
#  p1_p2_dist    0.290087
#  p1_p3_dist    0.706906
#  p2_p3_dist    0.923058
#  p1_acc        0.560778
#  p2_acc        0.445344
#  p3_acc        0.320096
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.255000
#  p2_survive    0.212000
#  p3_survive    0.826000
#  Name: 7352, dtype: float64,
#  p1_p2_dist    0.291011
#  p1_p3_dist    0.674168
#  p2_p3_dist    0.526214
#  p1_acc        0.601967
#  p2_acc        0.195244
#  p3_acc        0.111059
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.580000
#  p2_survive    0.095000
#  p3_survive    0.699000
#  Name: 7992, dtype: float64,
#  p1_p2_dist    0.291760
#  p1_p3_dist    0.581160
#  p2_p3_dist    0.416454
#  p1_acc        0.706987
#  p2_acc        0.552982
#  p3_acc        0.224228
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.208000
#  p2_survive    0.107000
#  p3_survive    0.776000
#  Name: 7448, dtype: float64,
#  p1_p2_dist    0.293854
#  p1_p3_dist    0.489911
#  p2_p3_dist    0.456184
#  p1_acc        0.716393
#  p2_acc        0.595615
#  p3_acc        0.271456
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.147000
#  p2_survive    0.112000
#  p3_survive    0.772000
#  Name: 1232, dtype: float64,
#  p1_p2_dist    0.296448
#  p1_p3_dist    0.745839
#  p2_p3_dist    1.030646
#  p1_acc        0.668501
#  p2_acc        0.575698
#  p3_acc        0.404271
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.147000
#  p2_survive    0.176000
#  p3_survive    0.860000
#  Name: 2240, dtype: float64,
#  p1_p2_dist    0.296814
#  p1_p3_dist    0.631242
#  p2_p3_dist    0.758926
#  p1_acc        0.839901
#  p2_acc        0.182495
#  p3_acc        0.163252
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.610000
#  p2_survive    0.015000
#  p3_survive    0.556000
#  Name: 1592, dtype: float64,
#  p1_p2_dist    0.297335
#  p1_p3_dist    0.543925
#  p2_p3_dist    0.259920
#  p1_acc        0.491534
#  p2_acc        0.322240
#  p3_acc        0.024668
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.468000
#  p2_survive    0.239000
#  p3_survive    0.717000
#  Name: 2048, dtype: float64,
#  p1_p2_dist    0.299278
#  p1_p3_dist    0.155712
#  p2_p3_dist    0.181944
#  p1_acc        0.741764
#  p2_acc        0.415985
#  p3_acc        0.238407
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.225000
#  p2_survive    0.077000
#  p3_survive    0.629000
#  Name: 6544, dtype: float64,
#  p1_p2_dist    0.301448
#  p1_p3_dist    0.631099
#  p2_p3_dist    0.466445
#  p1_acc        0.787010
#  p2_acc        0.246858
#  p3_acc        0.048562
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.672000
#  p2_survive    0.036000
#  p3_survive    0.561000
#  Name: 2473, dtype: float64,
#  p1_p2_dist    0.302281
#  p1_p3_dist    0.846114
#  p2_p3_dist    0.551902
#  p1_acc        0.608610
#  p2_acc        0.583133
#  p3_acc        0.368421
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.219000
#  p2_survive    0.114000
#  p3_survive    0.821000
#  Name: 5625, dtype: float64,
#  p1_p2_dist    0.303863
#  p1_p3_dist    0.163953
#  p2_p3_dist    0.215394
#  p1_acc        0.744538
#  p2_acc        0.206593
#  p3_acc        0.094663
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.561000
#  p2_survive    0.052000
#  p3_survive    0.395000
#  Name: 5768, dtype: float64,
#  p1_p2_dist    0.306722
#  p1_p3_dist    0.659523
#  p2_p3_dist    0.905896
#  p1_acc        0.293133
#  p2_acc        0.269366
#  p3_acc        0.027959
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.422000
#  p2_survive    0.390000
#  p3_survive    0.850000
#  Name: 7792, dtype: float64,
#  p1_p2_dist    0.307705
#  p1_p3_dist    0.653610
#  p2_p3_dist    0.652864
#  p1_acc        0.257651
#  p2_acc        0.125635
#  p3_acc        0.063717
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.542000
#  p2_survive    0.281000
#  p3_survive    0.857000
#  Name: 6328, dtype: float64,
#  p1_p2_dist    0.307891
#  p1_p3_dist    0.367481
#  p2_p3_dist    0.126880
#  p1_acc        0.860712
#  p2_acc        0.817291
#  p3_acc        0.184279
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.041000
#  p2_survive    0.025000
#  p3_survive    0.920000
#  Name: 224, dtype: float64,
#  p1_p2_dist    0.307919
#  p1_p3_dist    0.189371
#  p2_p3_dist    0.358792
#  p1_acc        0.534490
#  p2_acc        0.474190
#  p3_acc        0.280490
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.145000
#  p2_survive    0.233000
#  p3_survive    0.684000
#  Name: 600, dtype: float64,
#  p1_p2_dist    0.310567
#  p1_p3_dist    0.046342
#  p2_p3_dist    0.356191
#  p1_acc        0.575513
#  p2_acc        0.260871
#  p3_acc        0.255905
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.289000
#  p2_survive    0.701000
#  p3_survive    0.087000
#  Name: 5068, dtype: float64,
#  p1_p2_dist    0.311449
#  p1_p3_dist    0.236451
#  p2_p3_dist    0.510380
#  p1_acc        0.688324
#  p2_acc        0.275119
#  p3_acc        0.050690
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.507000
#  p2_survive    0.103000
#  p3_survive    0.526000
#  Name: 4312, dtype: float64,
#  p1_p2_dist    0.311932
#  p1_p3_dist    0.328660
#  p2_p3_dist    0.167416
#  p1_acc        0.449581
#  p2_acc        0.178106
#  p3_acc        0.066008
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.543000
#  p2_survive    0.205000
#  p3_survive    0.676000
#  Name: 4976, dtype: float64,
#  p1_p2_dist    0.313049
#  p1_p3_dist    0.481106
#  p2_p3_dist    0.179874
#  p1_acc        0.977273
#  p2_acc        0.612436
#  p3_acc        0.503384
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.233000
#  p2_survive    0.239000
#  p3_survive    0.047000
#  Name: 5197, dtype: float64,
#  p1_p2_dist    0.313183
#  p1_p3_dist    0.430578
#  p2_p3_dist    0.260144
#  p1_acc        0.826177
#  p2_acc        0.783145
#  p3_acc        0.203124
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.089000
#  p2_survive    0.054000
#  p3_survive    0.845000
#  Name: 4528, dtype: float64,
#  p1_p2_dist    0.315007
#  p1_p3_dist    0.828378
#  p2_p3_dist    0.803704
#  p1_acc        0.388722
#  p2_acc        0.360719
#  p3_acc        0.111885
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.343000
#  p2_survive    0.329000
#  p3_survive    0.841000
#  Name: 4952, dtype: float64,
#  p1_p2_dist    0.315226
#  p1_p3_dist    0.878110
#  p2_p3_dist    0.574505
#  p1_acc        0.693540
#  p2_acc        0.298832
#  p3_acc        0.222280
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.443000
#  p2_survive    0.091000
#  p3_survive    0.784000
#  Name: 2488, dtype: float64,
#  p1_p2_dist    0.315590
#  p1_p3_dist    0.401953
#  p2_p3_dist    0.307231
#  p1_acc        0.727880
#  p2_acc        0.666200
#  p3_acc        0.144108
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.207000
#  p2_survive    0.113000
#  p3_survive    0.741000
#  Name: 6825, dtype: float64,
#  p1_p2_dist    0.316128
#  p1_p3_dist    0.792316
#  p2_p3_dist    0.769875
#  p1_acc        0.722057
#  p2_acc        0.539807
#  p3_acc        0.002556
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.359000
#  p2_survive    0.123000
#  p3_survive    0.814000
#  Name: 5744, dtype: float64,
#  p1_p2_dist    0.316205
#  p1_p3_dist    0.461689
#  p2_p3_dist    0.614968
#  p1_acc        0.640905
#  p2_acc        0.326890
#  p3_acc        0.232780
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.327000
#  p2_survive    0.131000
#  p3_survive    0.701000
#  Name: 4016, dtype: float64,
#  p1_p2_dist    0.320186
#  p1_p3_dist    0.434101
#  p2_p3_dist    0.696519
#  p1_acc        0.548758
#  p2_acc        0.509607
#  p3_acc        0.149127
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.293000
#  p2_survive    0.209000
#  p3_survive    0.725000
#  Name: 4897, dtype: float64,
#  p1_p2_dist    0.321083
#  p1_p3_dist    0.774786
#  p2_p3_dist    0.665700
#  p1_acc        0.392991
#  p2_acc        0.282046
#  p3_acc        0.243317
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.305000
#  p2_survive    0.285000
#  p3_survive    0.834000
#  Name: 7704, dtype: float64,
#  p1_p2_dist    0.321638
#  p1_p3_dist    0.318632
#  p2_p3_dist    0.639622
#  p1_acc        0.665234
#  p2_acc        0.420792
#  p3_acc        0.097500
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.379000
#  p2_survive    0.147000
#  p3_survive    0.647000
#  Name: 1024, dtype: float64,
#  p1_p2_dist    0.323257
#  p1_p3_dist    0.775285
#  p2_p3_dist    0.788375
#  p1_acc        0.641792
#  p2_acc        0.564650
#  p3_acc        0.040164
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.284000
#  p2_survive    0.209000
#  p3_survive    0.809000
#  Name: 1992, dtype: float64,
#  p1_p2_dist    0.323837
#  p1_p3_dist    0.515336
#  p2_p3_dist    0.413492
#  p1_acc        0.427428
#  p2_acc        0.335847
#  p3_acc        0.234350
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.255000
#  p2_survive    0.257000
#  p3_survive    0.768000
#  Name: 976, dtype: float64,
#  p1_p2_dist    0.324329
#  p1_p3_dist    0.511230
#  p2_p3_dist    0.598792
#  p1_acc        0.893382
#  p2_acc        0.669667
#  p3_acc        0.537100
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.058000
#  p2_survive    0.017000
#  p3_survive    0.872000
#  Name: 2744, dtype: float64,
#  p1_p2_dist    0.324329
#  p1_p3_dist    0.511230
#  p2_p3_dist    0.598792
#  p1_acc        0.893382
#  p2_acc        0.669667
#  p3_acc        0.537100
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.131000
#  p2_survive    0.396000
#  p3_survive    0.093000
#  Name: 2749, dtype: float64,
#  p1_p2_dist    0.326258
#  p1_p3_dist    0.149403
#  p2_p3_dist    0.319837
#  p1_acc        0.910460
#  p2_acc        0.647543
#  p3_acc        0.132503
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.782000
#  p2_survive    0.005000
#  p3_survive    0.044000
#  Name: 7658, dtype: float64,
#  p1_p2_dist    0.326271
#  p1_p3_dist    0.572051
#  p2_p3_dist    0.872418
#  p1_acc        0.834338
#  p2_acc        0.617779
#  p3_acc        0.320540
#  p1_target     2.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.164000
#  p2_survive    0.056000
#  p3_survive    0.817000
#  Name: 1496, dtype: float64,
#  p1_p2_dist    0.326528
#  p1_p3_dist    0.390040
#  p2_p3_dist    0.264830
#  p1_acc        0.844553
#  p2_acc        0.614382
#  p3_acc        0.541471
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.366000
#  p2_survive    0.035000
#  p3_survive    0.161000
#  Name: 2634, dtype: float64,
#  p1_p2_dist    0.326528
#  p1_p3_dist    0.390040
#  p2_p3_dist    0.264830
#  p1_acc        0.844553
#  p2_acc        0.614382
#  p3_acc        0.541471
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.229000
#  p2_survive    0.256000
#  p3_survive    0.061000
#  Name: 2637, dtype: float64,
#  p1_p2_dist    0.326629
#  p1_p3_dist    0.404723
#  p2_p3_dist    0.725321
#  p1_acc        0.900469
#  p2_acc        0.892337
#  p3_acc        0.864983
# ...
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.733000
#  p2_survive    0.733000
#  p3_survive    0.082000
#  Name: 7828, dtype: float64,
#  p1_p2_dist    0.961084
#  p1_p3_dist    0.428344
#  p2_p3_dist    0.534692
#  p1_acc        0.707837
#  p2_acc        0.114213
#  p3_acc        0.029459
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.854000
#  p2_survive    0.695000
#  p3_survive    0.042000
#  Name: 4660, dtype: float64,
#  p1_p2_dist    0.962119
#  p1_p3_dist    0.877466
#  p2_p3_dist    0.573542
#  p1_acc        0.804880
#  p2_acc        0.688950
#  p3_acc        0.568801
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     2.000000
#  p1_survive    0.842000
#  p2_survive    0.143000
#  p3_survive    0.185000
#  Name: 1459, dtype: float64,
#  p1_p2_dist    0.962119
#  p1_p3_dist    0.877466
#  p2_p3_dist    0.573542
#  p1_acc        0.804880
#  p2_acc        0.688950
#  p3_acc        0.568801
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.446000
#  p2_survive    0.258000
#  p3_survive    0.285000
#  Name: 1461, dtype: float64,
#  p1_p2_dist    0.968404
#  p1_p3_dist    0.424757
#  p2_p3_dist    0.569030
#  p1_acc        0.424114
#  p2_acc        0.250588
#  p3_acc        0.179397
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.470000
#  p2_survive    0.861000
#  p3_survive    0.232000
#  Name: 2212, dtype: float64,
#  p1_p2_dist    0.970888
#  p1_p3_dist    0.113605
#  p2_p3_dist    0.901209
#  p1_acc        0.195242
#  p2_acc        0.137529
#  p3_acc        0.111693
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.442000
#  p2_survive    0.938000
#  p3_survive    0.356000
#  Name: 5364, dtype: float64,
#  p1_p2_dist    0.973335
#  p1_p3_dist    0.592506
#  p2_p3_dist    0.676594
#  p1_acc        0.869842
#  p2_acc        0.693093
#  p3_acc        0.559137
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.349000
#  p2_survive    0.409000
#  p3_survive    0.209000
#  Name: 554, dtype: float64,
#  p1_p2_dist    0.973335
#  p1_p3_dist    0.592506
#  p2_p3_dist    0.676594
#  p1_acc        0.869842
#  p2_acc        0.693093
#  p3_acc        0.559137
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.209000
#  p2_survive    0.800000
#  p3_survive    0.097000
#  Name: 556, dtype: float64,
#  p1_p2_dist    0.975531
#  p1_p3_dist    0.665619
#  p2_p3_dist    0.629899
#  p1_acc        0.624446
#  p2_acc        0.550066
#  p3_acc        0.356502
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.500000
#  p2_survive    0.485000
#  p3_survive    0.242000
#  Name: 3370, dtype: float64,
#  p1_p2_dist    0.975531
#  p1_p3_dist    0.665619
#  p2_p3_dist    0.629899
#  p1_acc        0.624446
#  p2_acc        0.550066
#  p3_acc        0.356502
#  p1_target     3.000000
#  p2_target     3.000000
#  p3_target     2.000000
#  p1_survive    0.814000
#  p2_survive    0.471000
#  p3_survive    0.067000
#  Name: 3375, dtype: float64,
#  p1_p2_dist    0.975549
#  p1_p3_dist    0.446467
#  p2_p3_dist    0.723966
#  p1_acc        0.978917
#  p2_acc        0.774293
#  p3_acc        0.371072
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.274000
#  p2_survive    0.820000
#  p3_survive    0.023000
#  Name: 596, dtype: float64,
#  p1_p2_dist    0.981221
#  p1_p3_dist    0.684089
#  p2_p3_dist    0.885602
#  p1_acc        0.948101
#  p2_acc        0.532496
#  p3_acc        0.489216
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.323000
#  p2_survive    0.788000
#  p3_survive    0.106000
#  Name: 7212, dtype: float64,
#  p1_p2_dist    0.981468
#  p1_p3_dist    0.443812
#  p2_p3_dist    0.896753
#  p1_acc        0.241374
#  p2_acc        0.175967
#  p3_acc        0.048096
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.555000
#  p2_survive    0.935000
#  p3_survive    0.268000
#  Name: 60, dtype: float64,
#  p1_p2_dist    0.984285
#  p1_p3_dist    0.876439
#  p2_p3_dist    0.337262
#  p1_acc        0.824973
#  p2_acc        0.611054
#  p3_acc        0.256577
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.701000
#  p2_survive    0.385000
#  p3_survive    0.107000
#  Name: 1890, dtype: float64,
#  p1_p2_dist    0.984819
#  p1_p3_dist    0.375191
#  p2_p3_dist    0.721066
#  p1_acc        0.651220
#  p2_acc        0.179572
#  p3_acc        0.059527
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.755000
#  p2_survive    0.765000
#  p3_survive    0.050000
#  Name: 180, dtype: float64,
#  p1_p2_dist    0.985894
#  p1_p3_dist    0.473809
#  p2_p3_dist    0.541920
#  p1_acc        0.784366
#  p2_acc        0.467705
#  p3_acc        0.323825
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.379000
#  p2_survive    0.819000
#  p3_survive    0.082000
#  Name: 6900, dtype: float64,
#  p1_p2_dist    0.991398
#  p1_p3_dist    0.143884
#  p2_p3_dist    1.133199
#  p1_acc        0.766197
#  p2_acc        0.573491
#  p3_acc        0.350812
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.339000
#  p2_survive    0.840000
#  p3_survive    0.017000
#  Name: 724, dtype: float64,
#  p1_p2_dist    0.999642
#  p1_p3_dist    0.745051
#  p2_p3_dist    0.349167
#  p1_acc        0.805923
#  p2_acc        0.805104
#  p3_acc        0.769493
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.345000
#  p2_survive    0.523000
#  p3_survive    0.049000
#  Name: 2722, dtype: float64,
#  p1_p2_dist    0.999642
#  p1_p3_dist    0.745051
#  p2_p3_dist    0.349167
#  p1_acc        0.805923
#  p2_acc        0.805104
#  p3_acc        0.769493
#  p1_target     3.000000
#  p2_target     3.000000
#  p3_target     2.000000
#  p1_survive    0.921000
#  p2_survive    0.106000
#  p3_survive    0.027000
#  Name: 2727, dtype: float64,
#  p1_p2_dist    1.000379
#  p1_p3_dist    0.708475
#  p2_p3_dist    0.293486
#  p1_acc        0.939345
#  p2_acc        0.554301
#  p3_acc        0.500905
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.619000
#  p2_survive    0.244000
#  p3_survive    0.130000
#  Name: 6437, dtype: float64,
#  p1_p2_dist    1.002481
#  p1_p3_dist    0.408027
#  p2_p3_dist    0.770948
#  p1_acc        0.819152
#  p2_acc        0.732589
#  p3_acc        0.187028
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.598000
#  p2_survive    0.407000
#  p3_survive    0.122000
#  Name: 3778, dtype: float64,
#  p1_p2_dist    1.002481
#  p1_p3_dist    0.408027
#  p2_p3_dist    0.770948
#  p1_acc        0.819152
#  p2_acc        0.732589
#  p3_acc        0.187028
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.356000
#  p2_survive    0.811000
#  p3_survive    0.040000
#  Name: 3780, dtype: float64,
#  p1_p2_dist    1.002659
#  p1_p3_dist    0.154461
#  p2_p3_dist    0.886791
#  p1_acc        0.781543
#  p2_acc        0.602119
#  p3_acc        0.524847
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.163000
#  p2_survive    0.923000
#  p3_survive    0.013000
#  Name: 1060, dtype: float64,
#  p1_p2_dist    1.004653
#  p1_p3_dist    0.472328
#  p2_p3_dist    0.545561
#  p1_acc        0.806746
#  p2_acc        0.683147
#  p3_acc        0.603527
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.569000
#  p2_survive    0.338000
#  p3_survive    0.085000
#  Name: 4125, dtype: float64,
#  p1_p2_dist    1.004653
#  p1_p3_dist    0.472328
#  p2_p3_dist    0.545561
#  p1_acc        0.806746
#  p2_acc        0.683147
#  p3_acc        0.603527
#  p1_target     3.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.278000
#  p2_survive    0.855000
#  p3_survive    0.018000
#  Name: 4126, dtype: float64,
#  p1_p2_dist    1.009002
#  p1_p3_dist    0.193993
#  p2_p3_dist    0.864466
#  p1_acc        0.660668
#  p2_acc        0.351662
#  p3_acc        0.252430
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.492000
#  p2_survive    0.839000
#  p3_survive    0.080000
#  Name: 460, dtype: float64,
#  p1_p2_dist    1.010345
#  p1_p3_dist    1.038954
#  p2_p3_dist    0.413434
#  p1_acc        0.875042
#  p2_acc        0.372883
#  p3_acc        0.322545
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     2.000000
#  p1_survive    0.913000
#  p2_survive    0.158000
#  p3_survive    0.316000
#  Name: 7571, dtype: float64,
#  p1_p2_dist    1.010967
#  p1_p3_dist    0.749738
#  p2_p3_dist    0.729751
#  p1_acc        0.887898
#  p2_acc        0.730834
#  p3_acc        0.673728
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.495000
#  p2_survive    0.327000
#  p3_survive    0.179000
#  Name: 1213, dtype: float64,
#  p1_p2_dist    1.013476
#  p1_p3_dist    0.810404
#  p2_p3_dist    0.335253
#  p1_acc        0.327063
#  p2_acc        0.179641
#  p3_acc        0.095033
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     2.000000
#  p1_survive    0.944000
#  p2_survive    0.348000
#  p3_survive    0.390000
#  Name: 4731, dtype: float64,
#  p1_p2_dist    1.015315
#  p1_p3_dist    0.529667
#  p2_p3_dist    0.500427
#  p1_acc        0.870158
#  p2_acc        0.693367
#  p3_acc        0.654132
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.584000
#  p2_survive    0.258000
#  p3_survive    0.084000
#  Name: 7205, dtype: float64,
#  p1_p2_dist    1.015315
#  p1_p3_dist    0.529667
#  p2_p3_dist    0.500427
#  p1_acc        0.870158
#  p2_acc        0.693367
#  p3_acc        0.654132
#  p1_target     3.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.294000
#  p2_survive    0.831000
#  p3_survive    0.017000
#  Name: 7206, dtype: float64,
#  p1_p2_dist    1.033194
#  p1_p3_dist    0.363733
#  p2_p3_dist    0.991516
#  p1_acc        0.564747
#  p2_acc        0.333100
#  p3_acc        0.318932
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.391000
#  p2_survive    0.882000
#  p3_survive    0.181000
#  Name: 6508, dtype: float64,
#  p1_p2_dist    1.033693
#  p1_p3_dist    0.502260
#  p2_p3_dist    0.587714
#  p1_acc        0.887876
#  p2_acc        0.593592
#  p3_acc        0.347745
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.383000
#  p2_survive    0.800000
#  p3_survive    0.054000
#  Name: 1044, dtype: float64,
#  p1_p2_dist    1.046585
#  p1_p3_dist    0.570960
#  p2_p3_dist    0.768378
#  p1_acc        0.825012
#  p2_acc        0.525273
#  p3_acc        0.448144
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.312000
#  p2_survive    0.850000
#  p3_survive    0.117000
#  Name: 4788, dtype: float64,
#  p1_p2_dist    1.049165
#  p1_p3_dist    0.476777
#  p2_p3_dist    0.575782
#  p1_acc        0.640619
#  p2_acc        0.544620
#  p3_acc        0.348887
#  p1_target     3.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.510000
#  p2_survive    0.825000
#  p3_survive    0.039000
#  Name: 3158, dtype: float64,
#  p1_p2_dist    1.058113
#  p1_p3_dist    0.642223
#  p2_p3_dist    0.447239
#  p1_acc        0.807404
#  p2_acc        0.321543
#  p3_acc        0.028304
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.899000
#  p2_survive    0.322000
#  p3_survive    0.175000
#  Name: 2754, dtype: float64,
#  p1_p2_dist    1.058113
#  p1_p3_dist    0.642223
#  p2_p3_dist    0.447239
#  p1_acc        0.807404
#  p2_acc        0.321543
#  p3_acc        0.028304
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.723000
#  p2_survive    0.731000
#  p3_survive    0.068000
#  Name: 2757, dtype: float64,
#  p1_p2_dist    1.059866
#  p1_p3_dist    0.720903
#  p2_p3_dist    0.348579
#  p1_acc        0.961327
#  p2_acc        0.221321
#  p3_acc        0.033576
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     2.000000
#  p1_survive    0.975000
#  p2_survive    0.179000
#  p3_survive    0.193000
#  Name: 4075, dtype: float64,
#  p1_p2_dist    1.059866
#  p1_p3_dist    0.720903
#  p2_p3_dist    0.348579
#  p1_acc        0.961327
#  p2_acc        0.221321
#  p3_acc        0.033576
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.787000
#  p2_survive    0.690000
#  p3_survive    0.040000
#  Name: 4076, dtype: float64,
#  p1_p2_dist    1.070807
#  p1_p3_dist    0.333840
#  p2_p3_dist    0.742592
#  p1_acc        0.919081
#  p2_acc        0.772958
#  p3_acc        0.041426
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.808000
#  p2_survive    0.398000
#  p3_survive    0.022000
#  Name: 6970, dtype: float64,
#  p1_p2_dist    1.070807
#  p1_p3_dist    0.333840
#  p2_p3_dist    0.742592
#  p1_acc        0.919081
#  p2_acc        0.772958
#  p3_acc        0.041426
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.520000
#  p2_survive    0.764000
#  p3_survive    0.002000
#  Name: 6973, dtype: float64,
#  p1_p2_dist    1.073957
#  p1_p3_dist    0.946215
#  p2_p3_dist    0.633620
#  p1_acc        0.249058
#  p2_acc        0.095871
#  p3_acc        0.002568
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     2.000000
#  p1_survive    0.982000
#  p2_survive    0.395000
#  p3_survive    0.463000
#  Name: 571, dtype: float64,
#  p1_p2_dist    1.073957
#  p1_p3_dist    0.946215
#  p2_p3_dist    0.633620
#  p1_acc        0.249058
#  p2_acc        0.095871
#  p3_acc        0.002568
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.741000
#  p2_survive    0.935000
#  p3_survive    0.195000
#  Name: 572, dtype: float64,
#  p1_p2_dist    1.080006
#  p1_p3_dist    1.043939
#  p2_p3_dist    0.861350
#  p1_acc        0.828550
#  p2_acc        0.755387
#  p3_acc        0.595258
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     2.000000
#  p1_survive    0.838000
#  p2_survive    0.211000
#  p3_survive    0.267000
#  Name: 7091, dtype: float64,
#  p1_p2_dist    1.110722
#  p1_p3_dist    0.503349
#  p2_p3_dist    1.041760
#  p1_acc        0.403028
#  p2_acc        0.259176
#  p3_acc        0.177175
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.517000
#  p2_survive    0.911000
#  p3_survive    0.256000
#  Name: 6636, dtype: float64,
#  p1_p2_dist    1.111086
#  p1_p3_dist    0.685900
#  p2_p3_dist    0.449583
#  p1_acc        0.836357
#  p2_acc        0.753880
#  p3_acc        0.102803
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.766000
#  p2_survive    0.535000
#  p3_survive    0.045000
#  Name: 2658, dtype: float64,
#  p1_p2_dist    1.111086
#  p1_p3_dist    0.685900
#  p2_p3_dist    0.449583
#  p1_acc        0.836357
#  p2_acc        0.753880
#  p3_acc        0.102803
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.524000
#  p2_survive    0.698000
#  p3_survive    0.073000
#  Name: 2661, dtype: float64,
#  p1_p2_dist    1.113564
#  p1_p3_dist    0.781617
#  p2_p3_dist    0.663997
#  p1_acc        0.894180
#  p2_acc        0.618125
#  p3_acc        0.227618
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.695000
#  p2_survive    0.457000
#  p3_survive    0.176000
#  Name: 4722, dtype: float64,
#  p1_p2_dist    1.113564
#  p1_p3_dist    0.781617
#  p2_p3_dist    0.663997
#  p1_acc        0.894180
#  p2_acc        0.618125
#  p3_acc        0.227618
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     2.000000
#  p1_survive    0.613000
#  p2_survive    0.587000
#  p3_survive    0.110000
#  Name: 4725, dtype: float64,
#  p1_p2_dist    1.124407
#  p1_p3_dist    0.751278
#  p2_p3_dist    0.760987
#  p1_acc        0.726002
#  p2_acc        0.713553
#  p3_acc        0.147992
#  p1_target     2.000000
#  p2_target     3.000000
#  p3_target     1.000000
#  p1_survive    0.736000
#  p2_survive    0.543000
#  p3_survive    0.153000
#  Name: 6106, dtype: float64,
#  p1_p2_dist    1.124407
#  p1_p3_dist    0.751278
#  p2_p3_dist    0.760987
#  p1_acc        0.726002
#  p2_acc        0.713553
#  p3_acc        0.147992
#  p1_target     3.000000
#  p2_target     1.000000
#  p3_target     1.000000
#  p1_survive    0.429000
#  p2_survive    0.858000
#  p3_survive    0.133000
#  Name: 6108, dtype: float64]

# %%
len(new)
# Out:
# 978

# %%
final = pd.concat(new, axis=1).T

# %%
final[final["p1_p2_dist"] < final["p1_p3_dist"]]
# Out:
#       p1_p2_dist  p1_p3_dist  p2_p3_dist    p1_acc    p2_acc    p3_acc  \
# 2908    0.442348    0.550732    0.109143  0.676996  0.670505  0.604477
# 2909    0.442348    0.550732    0.109143  0.676996  0.670505  0.604477
# 1234    0.462037    0.564889    0.109621  0.983241  0.937285  0.708011
# 1236    0.462037    0.564889    0.109621  0.983241  0.937285  0.708011
# 1237    0.462037    0.564889    0.109621  0.983241  0.937285  0.708011
# 2861    0.630729    0.778371    0.292995  0.993930  0.959640  0.762987
# 3082    0.642766    0.796545    0.200479  0.975781  0.925335  0.756497
# 3084    0.642766    0.796545    0.200479  0.975781  0.925335  0.756497
# 3085    0.642766    0.796545    0.200479  0.975781  0.925335  0.756497
# 2876    0.687442    0.723934    0.235206  0.449362  0.380248  0.335203
# 3256    0.688329    0.756596    0.184920  0.842229  0.792283  0.574116
# 868     0.806390    0.930118    0.124668  0.618807  0.583507  0.493260
#
#       p1_target  p2_target  p3_target  p1_survive  p2_survive  p3_survive
# 2908        3.0        1.0        1.0       0.175       0.898       0.439
# 2909        3.0        1.0        2.0       0.372       0.774       0.335
# 1234        2.0        3.0        1.0       0.295       0.302       0.645
# 1236        3.0        1.0        1.0       0.121       0.854       0.294
# 1237        3.0        1.0        2.0       0.271       0.681       0.236
# 2861        3.0        1.0        2.0       0.183       0.593       0.132
# 3082        2.0        3.0        1.0       0.158       0.224       0.585
# 3084        3.0        1.0        1.0       0.066       0.883       0.159
# 3085        3.0        1.0        2.0       0.157       0.617       0.140
# 2876        3.0        1.0        1.0       0.223       0.858       0.435
# 3256        2.0        1.0        1.0       0.104       0.298       0.855
# 868         3.0        1.0        1.0       0.104       0.883       0.337

# %%
p1 = equilibria["p1_survive"].idxmax()
p1 = p1.rename("best_row")
p2 = equilibria["p2_survive"].idxmax()
p2 = p2.rename("best_row")
p3 = equilibria["p3_survive"].idxmax()
p3 = p3.rename("best_row")

# %%
print(p1)
# Out:
# p1_p2_dist  p1_p3_dist  p2_p3_dist  p1_acc    p2_acc    p3_acc
# 0.018937    0.162379    0.143462    0.519741  0.353610  0.121470      43
# 0.022998    0.351561    0.342962    0.787060  0.741075  0.305841    1499
# 0.027225    0.246177    0.225832    0.996931  0.790407  0.557758    2475
# 0.028107    0.330523    0.332541    0.905358  0.905182  0.508952    1811
# 0.031700    0.388124    0.419172    0.728720  0.650869  0.297581    2099
#                                                                     ...
# 0.558763    0.423564    0.248868    0.817281  0.718262  0.219615    3723
# 0.568841    0.283616    0.417785    0.794518  0.489508  0.042661     563
# 0.582339    0.418234    0.441327    0.907019  0.793020  0.034184    3699
# 0.585237    0.405004    0.180770    0.917245  0.647201  0.320773     683
# 0.602957    0.059180    0.555220    0.361921  0.358141  0.020937    2003
# Name: best_row, Length: 500, dtype: int64

# %%
print(p2)
# Out:
# p1_p2_dist  p1_p3_dist  p2_p3_dist  p1_acc    p2_acc    p3_acc
# 0.018937    0.162379    0.143462    0.519741  0.353610  0.121470      44
# 0.022998    0.351561    0.342962    0.787060  0.741075  0.305841    1500
# 0.027225    0.246177    0.225832    0.996931  0.790407  0.557758    2476
# 0.028107    0.330523    0.332541    0.905358  0.905182  0.508952    1812
# 0.031700    0.388124    0.419172    0.728720  0.650869  0.297581    2100
#                                                                     ...
# 0.558763    0.423564    0.248868    0.817281  0.718262  0.219615    3724
# 0.568841    0.283616    0.417785    0.794518  0.489508  0.042661     564
# 0.582339    0.418234    0.441327    0.907019  0.793020  0.034184    3700
# 0.585237    0.405004    0.180770    0.917245  0.647201  0.320773     684
# 0.602957    0.059180    0.555220    0.361921  0.358141  0.020937    2004
# Name: best_row, Length: 500, dtype: int64

# %%
pd.merge(p1, p2, how='inner', on='best_row')
# Out:
# Empty DataFrame
# Columns: [best_row]
# Index: []
